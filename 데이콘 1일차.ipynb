# %% [markdown]
# ## 데이터 다운로드
# ---
# 아래 셀을 실행시켜 데이터를 colab에 불러옵니다.
# 셀 실행은 <br>Windows: `Ctrl` + `Enter`<br>
# Mac: `Shift` + `Enter` <br>
# 를 이용해 실행 시킬 수 있습니다.

# %%
# 데이터 다운로드 링크로 데이터를 코랩에 불러옵니다.

# !wget 'https://bit.ly/3gLj0Q6'

import zipfile
with zipfile.ZipFile('3gLj0Q6', 'r') as existing_zip:
    existing_zip.extractall('data')

# %% [markdown]
# ## 실습
# ---
# `data` 폴더에 있는 `test.csv` 파일과 `train.csv` 파일을 불러와 보세요.

# %%
import pandas as pd

train =  pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %% [markdown]
# ## 정답
# ---
# 스스로 실습 코드를 작성 한 후 정답 코드를 확인해 보세요.

# %%
import pandas as pd

# 정답 코드
train = pd.read_csv('data/train.csv') 
test = pd.read_csv('data/test.csv')

# %% [markdown]
# ## 2

# %% [markdown]
# ## 실습
# ---
# shape 를 이용해 train 과 test 의 행과 열의 갯수를 파악하는 코드를 아래 셀에서 실습해보세요

# %%
train.shape

# %%
test.shape

# %% [markdown]
# ## 정답
# ---
# 스스로 실습 코드를 작성 한 후 정답 코드를 확인해 보세요

# %%
train.shape

# %%
test.shape

# %% [markdown]
# ## 3

# %% [markdown]
# ## 실습
# ---
# head() 메서드를 이용해 `train 데이터의 상위 10개 행을 출력`해 보세요.

# %%
import pandas as pd

train = pd.read_csv('data/train.csv') 
'train 데이터의 상위 10개 행을 출력하는 코드 작성'
train.head(10)

# %% [markdown]
# ## 정답
# ---
# 스스로 실습 코드를 작성 한 후 정답 코드를 확인해 보세요.

# %%
import pandas as pd

train = pd.read_csv('data/train.csv')

# 정답 코드
train.head(100)

# %% [markdown]
# ## 4

# %% [markdown]
# ## 실습
# ---
# `train.csv` 의 결측치를 확인하는 코드를 작성해 보세요.

# %%
import pandas as pd


train = pd.read_csv('data/train.csv') 
test = pd.read_csv('data/test.csv')


print(train.isnull())
print('\n------------------------train.csv 각 열 별 결측치 수------------------------\n') 
print(test.isnull().sum()) #'train 데이터의 열별 결측치 수를 확인하는 코드를 작성해 보세요.'  #sum() : 디폴트값으로 axis = 0 즉 열방향 sum ,, axis=1 으로 하면 행방향 sum

# %% [markdown]
# ## 정답
# ---

# %%
import pandas as pd

# 정답 코드
train = pd.read_csv('data/train.csv') 
test = pd.read_csv('data/test.csv')

print(train.isnull())
print('\n--------------------------------train.csv 각 열 별 결측치 수--------------------------------\n')
print(test.isnull().sum())

# %% [markdown]
# ## 5

# %% [markdown]
# ## 데이터 불러오기
# ---
# 아래 셀을 실행시켜 train.csv 와 test.csv 를 dataframe 객체의 train 이라는 변수명과 test 라는 변수명으로 불러옵니다.

# %%
import pandas as pd

# 정답 코드
train = pd.read_csv('data/train.csv') 
test = pd.read_csv('data/test.csv')

# %% [markdown]
# ## 👋 실습
# ---
# DataFrame 객체의 info() 매서드를 사용해서 train 과 test 의 데이터 타입을 확인하는 코드를 아래에 작성하세요.

# %%
train.info()
test.info()

# %% [markdown]
# ## 정답
# ---
# 질문사항을 얼마든지 [게시글](https://dacon.io/competitions/open/235698/talkboard/403467?page=1&dtype=recent)에 남겨주세요 😉 <br>
# 궁금한 것, 이해가 안 되는 것, 원리, 확장개념, 참고 등등 모든 범위에서 얼마든지 질문을 달아주세요 🙋

# %%
# 정답 코드
train.info()
test.info()

# %% [markdown]
# ## 6. dropna() 를 사용하면, 결측치를 갖는 행을 DataFrame 객체에서 삭제
# # 또는 fillna() 를 사용해 모든 결측치를 인자값으로 대체

# %% [markdown]
# ## 👋 실습
# ---
# DataFrame 객체의 dropna() 매서드를 사용해서 train 과 test 의 결측치를 삭제하는 코드를 아래에 작성하세요.

# %%
train.dropna()

# %%
test.dropna()

# %% [markdown]
# ## 정답
# ---
# 질문사항을 얼마든지 [게시글](https://dacon.io/competitions/open/235698/talkboard/403490)에 남겨주세요 😉 <br>
# 궁금한 것, 이해가 안 되는 것, 원리, 확장개념, 참고 등등 모든 범위에서 얼마든지 질문을 달아주세요 🙋

# %%
# 정답 코드

train = train.dropna()
test = test.fillna(0)

# %% [markdown]
# ## 7 의사경정나무 decision tree

# %% [markdown]
# ## 👋 실습
# ---
# scikit-learn 으로부터 의사결정나무 모듈을 불러오는 코드를 아래에 작성하세요.

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %% [markdown]
# ## 정답
# ---

# %%
# 정답 코드
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %% [markdown]
# ## 8

# %% [markdown]
# ## 라이브러리 불러오기
# ---
# 아래 셀을 실행시켜 pandas 와 DecisionTreeClassifier 를 불러옵니다.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ## 데이터 불러오기
# ---
# 아래 셀을 실행시켜 csv 파일 데이터를 DataFrame 객체로 불러옵니다.

# %%
train = pd.read_csv('data/train.csv') 
test = pd.read_csv('data/test.csv')

# %% [markdown]
# ## 결측치 제거하기
# ---
# 결측치를 제거하고, 결측치가 모두 제거됐는지 확인합니다.

# %%
test = test.dropna()
train = train.dropna()

print(train.isnull().sum())

# %% [markdown]
# https://hogni.tistory.com/49  : drop() 함수 설명

# %% [markdown]
# ## 👋 실습(1/2)
# ---
# train 데이터중 <br>
# 예측해야할 `count` 피쳐를 drop()함수를 사용하고, axis=1 옵션을 사용해 해당 열을 제외한 데이터들을 `X_train` 이라는 이름의 DataFrame 객체로 만들고 <br>
# `count` 피쳐만을 데이터로 갖는 `Y_train` 이라는 이름의 DataFrame 객체로 만드는 코드를 아래에 작성하세요

# %%
X_train = train.drop(['count'], axis=1)
Y_train = train['count']

# %% [markdown]
# ## 👋 실습(2/2)
# ---
# `model` 변수명으로 모델을 선언하고, fit() 함수를 사용해서, `X_train` 을 input 으로 삼고, `Y_train` 을 output 으로 삼아 모델을 훈련시키는 코드를 아래에 작성하세요

# %%
model = DecisionTreeRegressor()
model.fit(X_train, Y_train)

# %% [markdown]
# ## 정답 (`숨겨진 셀 n개` 를 누르세요.)
# ---
# 질문사항을 얼마든지 [게시글](https://dacon.io/competitions/open/235698/talkboard/403540?page=2&dtype=recent)에 남겨주세요 😉 <br>
# 궁금한 것, 이해가 안 되는 것, 원리, 확장개념, 참고 등등 모든 범위에서 얼마든지 질문을 달아주세요 🙋

# %%
X_train = train.drop(['count'], axis=1)
Y_train = train['count']

# %%
model = DecisionTreeRegressor()
model.fit(X_train, Y_train)

# %% [markdown]
# ## 9

# %% [markdown]
# ## 👋 실습
# ---
# predict() 를 이용해 test data 를 훈련된 모델로 예측한 data 를 생성하고 예측결과 상위 5개를 출력하는 코드를 작성하세요.

# %%
test

# %%
pred = model.predict(test)
pred[:5]

# %% [markdown]
# ## 정답 (`숨겨진 셀 n개` 를 누르세요.)
# ---
# 질문사항을 얼마든지 [게시글](https://dacon.io/competitions/open/235698/talkboard/403540?page=1&dtype=recent)에 남겨주세요 😉 <br>
# 궁금한 것, 이해가 안 되는 것, 원리, 확장개념, 참고 등등 모든 범위에서 얼마든지 질문을 달아주세요 🙋

# %%
pred = model.predict(test)
pred[:5]

# %% [markdown]
# ## 10

# %% [markdown]
# ## 👋 실습
# ---
# 1. submission.csv 파일을 read_csv() 를 이용해 df 클래스로 불러옵니다.
# 2. submission df 파일의 `count` 피쳐를 예측결과로 할당합니다.
# 3. submission df 파일을 to_csv() 를 이용해 csv 파일로 내보닙니다. 여기서 index 옵션은 False 로 지정해주어야 정답 형식과 맞아 떨어져 헤더 오류가 나지 않습니다.

# %%
# submission.csv 파일 df 파일로 불러오기
submission = pd.read_csv('data/submission.csv')
submission

# %%
# submission df 파일의 count 피쳐에 예측결과 할당하기
submission['count'] = pred
submission

# %%
submission.to_csv('sub.csv',index=False) # 제출파일 생성하기

# %% [markdown]
# ## 정답 (`숨겨진 셀 n개` 를 누르세요.)
# ---
# 질문사항을 얼마든지 [게시글](https://dacon.io/competitions/open/235698/talkboard/403540?page=1&dtype=recent)에 남겨주세요 😉 <br>
# 궁금한 것, 이해가 안 되는 것, 원리, 확장개념, 참고 등등 모든 범위에서 얼마든지 질문을 달아주세요 🙋

# %%
submission = pd.read_csv('data/submission.csv')

# %%
submission['count'] = pred

# %%
submission.to_csv('gdrive/MyDrive/sub.csv',index=False)

# %%
ls 3gLj0Q6

# %% [markdown]
# 드라이브 연동

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
ls gdrive/
